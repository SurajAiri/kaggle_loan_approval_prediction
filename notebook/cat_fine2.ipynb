# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
NUM_FOLD = 3

train = pd.read_csv('../dataset/train.csv', index_col='id')
test = pd.read_csv('../dataset/test.csv', index_col='id')


# cat_cols = list(test.select_dtypes(include=['object']).columns)
cat_cols = test.columns.values
print(cat_cols)

for df in [train, test]:
    for col in cat_cols:
        if df[col].dtype == 'float64':
            df[col] = df[col].round(decimals=2).astype('str').astype('category')
        else:
            df[col] = df[col].astype('str').astype('category')

# train['person_home_ownership'] = train['person_home_ownership'].astype(str)
# test['person_home_ownership'] = test['person_home_ownership'].astype(str)



X = train.drop(['loan_status'], axis=1)
y = train['loan_status']

X, _, y, _ = train_test_split(X, y, test_size=0.8, random_state=42, stratify=y)
# Out:
# ['person_age' 'person_income' 'person_home_ownership' 'person_emp_length'
#  'loan_intent' 'loan_grade' 'loan_amnt' 'loan_int_rate'
#  'loan_percent_income' 'cb_person_default_on_file'
#  'cb_person_cred_hist_length']

# %%
X.value_counts()
# Out:
# person_age  person_income  person_home_ownership  person_emp_length  loan_intent        loan_grade  loan_amnt  loan_int_rate  loan_percent_income  cb_person_default_on_file  cb_person_cred_hist_length
# 21          109000         OWN                    5.0                VENTURE            B           15000      11.48          0.14                 N                          3                             1
# 28          60000          MORTGAGE               3.0                HOMEIMPROVEMENT    A           15000      7.49           0.25                 N                          8                             1
#                                                                      PERSONAL           B           6000       11.48          0.1                  N                          10                            1
#                                                   4.0                DEBTCONSOLIDATION  A           4800       7.9            0.08                 N                          10                            1
#                                                                                                     7200       7.88           0.12                 N                          9                             1
#                                                                                                                                                                                                            ..
# 24          48000          RENT                   1.0                MEDICAL            A           1500       8.94           0.03                 N                          4                             1
#                                                                                         C           10000      14.22          0.21                 N                          3                             1
#                                                                      VENTURE            B           11200      11.48          0.23                 N                          4                             1
#                                                   2.0                DEBTCONSOLIDATION  B           15000      10.37          0.31                 N                          4                             1
# 76          30000          RENT                   2.0                HOMEIMPROVEMENT    D           6500       16.77          0.21                 N                          24                            1
# Name: count, Length: 11729, dtype: int64

# %%
def objective_func(trial):

# # test 1
    params = {
    'iterations': trial.suggest_int('iterations', 200, 1000),
    'depth': trial.suggest_int('depth', 3, 15),
    'learning_rate': trial.suggest_float('learning_rate', 1e-3, 0.1),
    'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 0, 10),
    'border_count': trial.suggest_int('border_count', 32, 256),
    'random_strength': trial.suggest_float('random_strength', 0.5, 8),
    'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1.5),
    # 'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli']),
    'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
    'verbose': False,
    'task_type': 'CPU',
}

    # # test 2
    # params = {
    #     'iterations': trial.suggest_int('iterations', 600, 1500),
    #     'depth': trial.suggest_int('depth', 1, 8),
    #     'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
    #     'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 6, 15),
    #     'border_count': trial.suggest_int('border_count', 190, 300),
    #     'random_strength': trial.suggest_float('random_strength', 6, 12),
    #     'bagging_temperature': trial.suggest_float('bagging_temperature', 0.5, 1.5),
    #     'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0, 8),
    #     'verbose': False,
    #     'task_type': 'CPU',
    # }

    # # test 3
    # params = {
    #     'iterations': trial.suggest_int('iterations', 800, 1500),
    #     'depth': trial.suggest_int('depth', 2, 6),
    #     'learning_rate': trial.suggest_float('learning_rate', 0.05, 0.1),
    #     'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 5, 10),
    #     'border_count': trial.suggest_int('border_count', 210, 350),
    #     'random_strength': trial.suggest_float('random_strength', 4,10),
    #     'bagging_temperature': trial.suggest_float('bagging_temperature',1,2),
    #     'scale_pos_weight': trial.suggest_float('scale_pos_weight', 2, 8),
    #     'verbose': False,
    #     'task_type': 'CPU',
    # }


    skf = StratifiedKFold(n_splits=NUM_FOLD, shuffle=True, random_state=42)
    scores = []

    for train_idx, valid_idx in skf.split(X, y):
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        model = CatBoostClassifier(**params,cat_features=cat_cols)
        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)], early_stopping_rounds=100, verbose=False)
        y_pred = model.predict_proba(X_valid)[:, 1]
        score = roc_auc_score(y_valid, y_pred)
        scores.append(score)

    return np.mean(scores)

# %%
import optuna

study = optuna.create_study(direction='maximize', study_name="Catboost all columns Category")
study.optimize(objective_func, n_trials=100)
# Out:
# [I 2024-10-15 12:18:46,861] A new study created in memory with name: Catboost all columns Category
# [I 2024-10-15 12:18:53,634] Trial 0 finished with value: 0.9514978324474469 and parameters: {'iterations': 521, 'depth': 9, 'learning_rate': 0.0782336490137188, 'l2_leaf_reg': 5.234033707272165, 'border_count': 232, 'random_strength': 2.1608017371977004, 'bagging_temperature': 1.0902045782493959, 'scale_pos_weight': 8.340148324714708}. Best is trial 0 with value: 0.9514978324474469.
# [I 2024-10-15 12:18:59,648] Trial 1 finished with value: 0.9526205010319512 and parameters: {'iterations': 612, 'depth': 3, 'learning_rate': 0.06131160202159489, 'l2_leaf_reg': 7.1984460677101385, 'border_count': 94, 'random_strength': 0.6078407544176783, 'bagging_temperature': 0.4578211370962242, 'scale_pos_weight': 7.602523970125969}. Best is trial 1 with value: 0.9526205010319512.
# [I 2024-10-15 12:19:04,684] Trial 2 finished with value: 0.9520003292715365 and parameters: {'iterations': 224, 'depth': 8, 'learning_rate': 0.08097157085886428, 'l2_leaf_reg': 7.152326657105384, 'border_count': 50, 'random_strength': 2.6138844494182156, 'bagging_temperature': 0.8398313255355505, 'scale_pos_weight': 7.723391664907287}. Best is trial 1 with value: 0.9526205010319512.
# [I 2024-10-15 12:19:12,471] Trial 3 finished with value: 0.9520211687586643 and parameters: {'iterations': 958, 'depth': 8, 'learning_rate': 0.05041265595100658, 'l2_leaf_reg': 8.556707905027949, 'border_count': 95, 'random_strength': 6.999582310196439, 'bagging_temperature': 1.4189953544829106, 'scale_pos_weight': 7.518732696165115}. Best is trial 1 with value: 0.9526205010319512.
# [I 2024-10-15 12:19:18,796] Trial 4 finished with value: 0.9520690101142626 and parameters: {'iterations': 731, 'depth': 6, 'learning_rate': 0.062214939406317234, 'l2_leaf_reg': 7.3993095516558665, 'border_count': 34, 'random_strength': 7.9857205947005845, 'bagging_temperature': 0.4591881698668718, 'scale_pos_weight': 8.092835045615796}. Best is trial 1 with value: 0.9526205010319512.
# [I 2024-10-15 12:19:26,026] Trial 5 finished with value: 0.9423417709350771 and parameters: {'iterations': 480, 'depth': 6, 'learning_rate': 0.0035235545955098384, 'l2_leaf_reg': 3.5836752293331218, 'border_count': 172, 'random_strength': 6.742176717524364, 'bagging_temperature': 0.12650181757601076, 'scale_pos_weight': 6.365381381678437}. Best is trial 1 with value: 0.9526205010319512.
# [I 2024-10-15 12:20:18,027] Trial 6 finished with value: 0.9508840487366609 and parameters: {'iterations': 530, 'depth': 14, 'learning_rate': 0.04000955490883715, 'l2_leaf_reg': 2.855993489138209, 'border_count': 246, 'random_strength': 4.23471271145231, 'bagging_temperature': 0.6615491309532222, 'scale_pos_weight': 2.7079981752760225}. Best is trial 1 with value: 0.9526205010319512.
# [I 2024-10-15 12:21:58,637] Trial 7 finished with value: 0.9488357899608615 and parameters: {'iterations': 514, 'depth': 15, 'learning_rate': 0.07261578641393028, 'l2_leaf_reg': 2.5086800351028637, 'border_count': 145, 'random_strength': 6.639141161939571, 'bagging_temperature': 0.9360159935323444, 'scale_pos_weight': 4.525026478521224}. Best is trial 1 with value: 0.9526205010319512.
# [I 2024-10-15 12:22:07,840] Trial 8 finished with value: 0.9526913653678216 and parameters: {'iterations': 373, 'depth': 9, 'learning_rate': 0.05779335152497437, 'l2_leaf_reg': 3.480799265495799, 'border_count': 129, 'random_strength': 7.840116001496498, 'bagging_temperature': 0.7939823549703867, 'scale_pos_weight': 3.5154025524573664}. Best is trial 8 with value: 0.9526913653678216.
# [I 2024-10-15 12:22:29,075] Trial 9 finished with value: 0.9491806698460561 and parameters: {'iterations': 287, 'depth': 13, 'learning_rate': 0.0922094499589045, 'l2_leaf_reg': 4.983880340431951, 'border_count': 83, 'random_strength': 2.80836200304073, 'bagging_temperature': 1.1990992827113554, 'scale_pos_weight': 8.763704781457019}. Best is trial 8 with value: 0.9526913653678216.
# [I 2024-10-15 12:22:42,867] Trial 10 finished with value: 0.9516192538625265 and parameters: {'iterations': 325, 'depth': 11, 'learning_rate': 0.029562452425373392, 'l2_leaf_reg': 0.10682351484857344, 'border_count': 186, 'random_strength': 4.946629465640691, 'bagging_temperature': 0.04073882686834296, 'scale_pos_weight': 1.160108198326018}. Best is trial 8 with value: 0.9526913653678216.
# [I 2024-10-15 12:22:49,165] Trial 11 finished with value: 0.952956229955801 and parameters: {'iterations': 724, 'depth': 3, 'learning_rate': 0.056266683859294564, 'l2_leaf_reg': 5.755749838214193, 'border_count': 107, 'random_strength': 1.3079823118291456, 'bagging_temperature': 0.44777250133673036, 'scale_pos_weight': 4.76455713248548}. Best is trial 11 with value: 0.952956229955801.
# [I 2024-10-15 12:22:58,522] Trial 12 finished with value: 0.9533672174874491 and parameters: {'iterations': 765, 'depth': 4, 'learning_rate': 0.024986904452343243, 'l2_leaf_reg': 5.368718031122307, 'border_count': 131, 'random_strength': 0.5887642708591994, 'bagging_temperature': 0.5185866369676857, 'scale_pos_weight': 4.345882780991873}. Best is trial 12 with value: 0.9533672174874491.
# [I 2024-10-15 12:23:07,112] Trial 13 finished with value: 0.9526348179672999 and parameters: {'iterations': 820, 'depth': 3, 'learning_rate': 0.018169655205139315, 'l2_leaf_reg': 5.028341690235224, 'border_count': 133, 'random_strength': 0.613770092036727, 'bagging_temperature': 0.359118596199216, 'scale_pos_weight': 5.539913856743267}. Best is trial 12 with value: 0.9533672174874491.
# [I 2024-10-15 12:23:18,833] Trial 14 finished with value: 0.9537133168802084 and parameters: {'iterations': 747, 'depth': 5, 'learning_rate': 0.03150990908465595, 'l2_leaf_reg': 9.796691879442918, 'border_count': 181, 'random_strength': 1.4949524121774718, 'bagging_temperature': 0.27802876675024707, 'scale_pos_weight': 3.870381357639382}. Best is trial 14 with value: 0.9537133168802084.
# [I 2024-10-15 12:23:32,576] Trial 15 finished with value: 0.953789986958068 and parameters: {'iterations': 950, 'depth': 5, 'learning_rate': 0.019969673884658284, 'l2_leaf_reg': 9.93457820145145, 'border_count': 198, 'random_strength': 3.8599516313307287, 'bagging_temperature': 0.2499809391055463, 'scale_pos_weight': 2.730868842973977}. Best is trial 15 with value: 0.953789986958068.
# [I 2024-10-15 12:23:46,221] Trial 16 finished with value: 0.9503868559198082 and parameters: {'iterations': 997, 'depth': 5, 'learning_rate': 0.007000898729640645, 'l2_leaf_reg': 9.69767129602816, 'border_count': 211, 'random_strength': 4.073583457549819, 'bagging_temperature': 0.22277151189719513, 'scale_pos_weight': 2.238413475942175}. Best is trial 15 with value: 0.953789986958068.
# [I 2024-10-15 12:23:56,255] Trial 17 finished with value: 0.9529851739197616 and parameters: {'iterations': 878, 'depth': 6, 'learning_rate': 0.038553689701178166, 'l2_leaf_reg': 9.757430472960442, 'border_count': 188, 'random_strength': 5.383237166296035, 'bagging_temperature': 0.2267921646622008, 'scale_pos_weight': 9.745198842887788}. Best is trial 15 with value: 0.953789986958068.
# [I 2024-10-15 12:24:29,096] Trial 18 finished with value: 0.9534311682843821 and parameters: {'iterations': 663, 'depth': 11, 'learning_rate': 0.016487309665699446, 'l2_leaf_reg': 8.705345528674147, 'border_count': 214, 'random_strength': 3.2999013355949467, 'bagging_temperature': 0.6456080523729929, 'scale_pos_weight': 1.108143878352605}. Best is trial 15 with value: 0.953789986958068.
# [I 2024-10-15 12:24:37,867] Trial 19 finished with value: 0.9543833160697416 and parameters: {'iterations': 879, 'depth': 7, 'learning_rate': 0.03965079990826937, 'l2_leaf_reg': 8.828188670516887, 'border_count': 163, 'random_strength': 1.6751438568288988, 'bagging_temperature': 0.2739378678903753, 'scale_pos_weight': 3.0452472860582653}. Best is trial 19 with value: 0.9543833160697416.
# [I 2024-10-15 12:24:48,460] Trial 20 finished with value: 0.954510724275051 and parameters: {'iterations': 890, 'depth': 7, 'learning_rate': 0.04446136194774551, 'l2_leaf_reg': 8.377675413026191, 'border_count': 159, 'random_strength': 5.277687045977382, 'bagging_temperature': 0.07755145540190786, 'scale_pos_weight': 2.502344594890521}. Best is trial 20 with value: 0.954510724275051.
# [I 2024-10-15 12:24:58,980] Trial 21 finished with value: 0.9550143699850512 and parameters: {'iterations': 891, 'depth': 7, 'learning_rate': 0.0448563477253477, 'l2_leaf_reg': 8.309884320742215, 'border_count': 161, 'random_strength': 5.297381835241815, 'bagging_temperature': 0.10498408144882451, 'scale_pos_weight': 2.3753101495123747}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:25:10,217] Trial 22 finished with value: 0.9541886278985192 and parameters: {'iterations': 865, 'depth': 7, 'learning_rate': 0.045137826579015966, 'l2_leaf_reg': 8.265615885929554, 'border_count': 156, 'random_strength': 5.379556095538451, 'bagging_temperature': 0.025077022606324204, 'scale_pos_weight': 2.0893530424989537}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:25:21,403] Trial 23 finished with value: 0.9533620235857913 and parameters: {'iterations': 893, 'depth': 8, 'learning_rate': 0.03967249752160264, 'l2_leaf_reg': 6.3701497780806395, 'border_count': 152, 'random_strength': 6.037730447073064, 'bagging_temperature': 0.1222563505738318, 'scale_pos_weight': 3.0104644413928474}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:25:35,804] Trial 24 finished with value: 0.9529841072117757 and parameters: {'iterations': 819, 'depth': 11, 'learning_rate': 0.06969710151007302, 'l2_leaf_reg': 7.8244822133423195, 'border_count': 165, 'random_strength': 4.908319763836508, 'bagging_temperature': 0.01290092482029273, 'scale_pos_weight': 1.7127477012897785}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:25:45,548] Trial 25 finished with value: 0.953613744520904 and parameters: {'iterations': 924, 'depth': 7, 'learning_rate': 0.04703639548000064, 'l2_leaf_reg': 8.955823778043785, 'border_count': 116, 'random_strength': 6.0843226115220626, 'bagging_temperature': 0.14766109840708358, 'scale_pos_weight': 3.511679825954466}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:25:58,911] Trial 26 finished with value: 0.9525447541717166 and parameters: {'iterations': 814, 'depth': 10, 'learning_rate': 0.03514510778805832, 'l2_leaf_reg': 6.417027330457386, 'border_count': 164, 'random_strength': 4.9184403906937, 'bagging_temperature': 0.3619302912113008, 'scale_pos_weight': 5.854564098552375}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:26:08,263] Trial 27 finished with value: 0.9545112991995176 and parameters: {'iterations': 668, 'depth': 7, 'learning_rate': 0.05206996020178483, 'l2_leaf_reg': 9.139879841413228, 'border_count': 205, 'random_strength': 3.446476493443063, 'bagging_temperature': 0.5678696666471219, 'scale_pos_weight': 1.8083927899578303}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:26:20,815] Trial 28 finished with value: 0.9532851599403976 and parameters: {'iterations': 658, 'depth': 10, 'learning_rate': 0.05353808931697814, 'l2_leaf_reg': 6.707995573657891, 'border_count': 212, 'random_strength': 3.315148973291319, 'bagging_temperature': 0.6209354075775635, 'scale_pos_weight': 1.6788159292986218}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:26:29,391] Trial 29 finished with value: 0.9529799276938782 and parameters: {'iterations': 413, 'depth': 8, 'learning_rate': 0.06691000334947178, 'l2_leaf_reg': 7.946544156442206, 'border_count': 234, 'random_strength': 5.855595313583946, 'bagging_temperature': 1.3190909019051242, 'scale_pos_weight': 1.7809718254198226}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:26:40,913] Trial 30 finished with value: 0.9526105385635981 and parameters: {'iterations': 675, 'depth': 9, 'learning_rate': 0.08558647948081576, 'l2_leaf_reg': 9.14641891231061, 'border_count': 253, 'random_strength': 3.451900339920242, 'bagging_temperature': 1.0524900758486864, 'scale_pos_weight': 2.3495128954494895}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:26:53,148] Trial 31 finished with value: 0.9541718854303568 and parameters: {'iterations': 993, 'depth': 7, 'learning_rate': 0.0447055643814594, 'l2_leaf_reg': 9.114396770925659, 'border_count': 195, 'random_strength': 4.63138857256088, 'bagging_temperature': 0.3389228454217391, 'scale_pos_weight': 3.120502589355578}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:27:05,028] Trial 32 finished with value: 0.9534773115102048 and parameters: {'iterations': 840, 'depth': 7, 'learning_rate': 0.05209748689578856, 'l2_leaf_reg': 7.8252992727928365, 'border_count': 175, 'random_strength': 2.1926321359213157, 'bagging_temperature': 0.12787342036624078, 'scale_pos_weight': 1.0737127910235287}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:27:10,992] Trial 33 finished with value: 0.9540396033678862 and parameters: {'iterations': 574, 'depth': 6, 'learning_rate': 0.06401502735053721, 'l2_leaf_reg': 7.120879012159925, 'border_count': 225, 'random_strength': 1.6553478450904828, 'bagging_temperature': 0.55283278677399, 'scale_pos_weight': 3.9410101022219393}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:27:20,880] Trial 34 finished with value: 0.9535069649007824 and parameters: {'iterations': 920, 'depth': 8, 'learning_rate': 0.044496239186735564, 'l2_leaf_reg': 8.356473545658188, 'border_count': 148, 'random_strength': 2.7478265575251064, 'bagging_temperature': 0.17246663357086034, 'scale_pos_weight': 2.4547331657474016}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:27:30,616] Trial 35 finished with value: 0.9537573642479394 and parameters: {'iterations': 780, 'depth': 4, 'learning_rate': 0.027775895505207773, 'l2_leaf_reg': 9.283559837452586, 'border_count': 79, 'random_strength': 5.406981001221217, 'bagging_temperature': 0.31008858009303286, 'scale_pos_weight': 3.2754441689398206}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:27:35,867] Trial 36 finished with value: 0.9532427015598861 and parameters: {'iterations': 607, 'depth': 6, 'learning_rate': 0.07547868852442287, 'l2_leaf_reg': 7.464393574621882, 'border_count': 201, 'random_strength': 1.992186471258761, 'bagging_temperature': 0.4312795917198119, 'scale_pos_weight': 6.718061811593223}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:27:48,827] Trial 37 finished with value: 0.9543147848165194 and parameters: {'iterations': 703, 'depth': 8, 'learning_rate': 0.04843710429591872, 'l2_leaf_reg': 8.536374299392648, 'border_count': 118, 'random_strength': 3.667833489646135, 'bagging_temperature': 0.08443227858470925, 'scale_pos_weight': 1.622510933431865}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:27:59,769] Trial 38 finished with value: 0.95374143136074 and parameters: {'iterations': 780, 'depth': 7, 'learning_rate': 0.03567693327010125, 'l2_leaf_reg': 7.083187316089369, 'border_count': 162, 'random_strength': 7.439567128253692, 'bagging_temperature': 0.9291499836230344, 'scale_pos_weight': 4.883815017256747}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:28:09,292] Trial 39 finished with value: 0.9535309964866793 and parameters: {'iterations': 952, 'depth': 9, 'learning_rate': 0.05982220831903135, 'l2_leaf_reg': 4.223309805911879, 'border_count': 142, 'random_strength': 4.524071135956852, 'bagging_temperature': 0.6936564875616017, 'scale_pos_weight': 2.901163722002129}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:28:19,429] Trial 40 finished with value: 0.9538658699254908 and parameters: {'iterations': 898, 'depth': 5, 'learning_rate': 0.041715553470649994, 'l2_leaf_reg': 0.37555027021167753, 'border_count': 174, 'random_strength': 6.403161860842022, 'bagging_temperature': 0.5546308014801875, 'scale_pos_weight': 4.004946196417802}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:28:28,592] Trial 41 finished with value: 0.9532672300654225 and parameters: {'iterations': 716, 'depth': 8, 'learning_rate': 0.04984589219184527, 'l2_leaf_reg': 8.46003731291379, 'border_count': 113, 'random_strength': 3.825533404853287, 'bagging_temperature': 0.05535599700353869, 'scale_pos_weight': 1.6453350324392302}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:28:39,463] Trial 42 finished with value: 0.954253255058295 and parameters: {'iterations': 684, 'depth': 9, 'learning_rate': 0.05365230712381862, 'l2_leaf_reg': 8.738092865110396, 'border_count': 125, 'random_strength': 4.402910284598774, 'bagging_temperature': 0.07287908968564216, 'scale_pos_weight': 2.140918323079508}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:28:48,469] Trial 43 finished with value: 0.9543221541861339 and parameters: {'iterations': 633, 'depth': 8, 'learning_rate': 0.04907033048126164, 'l2_leaf_reg': 9.358424072001437, 'border_count': 96, 'random_strength': 2.4130501836662566, 'bagging_temperature': 0.21323416615476212, 'scale_pos_weight': 1.4492195888997892}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:28:57,837] Trial 44 finished with value: 0.9544998973334492 and parameters: {'iterations': 576, 'depth': 6, 'learning_rate': 0.033378637983255084, 'l2_leaf_reg': 9.251476467192395, 'border_count': 49, 'random_strength': 2.288795383315809, 'bagging_temperature': 0.19216646998408174, 'scale_pos_weight': 2.666221677014072}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:29:07,004] Trial 45 finished with value: 0.9542581173591856 and parameters: {'iterations': 557, 'depth': 6, 'learning_rate': 0.026413649065865432, 'l2_leaf_reg': 7.90946546508541, 'border_count': 54, 'random_strength': 1.0161495241022158, 'bagging_temperature': 0.4067001257796927, 'scale_pos_weight': 3.371163375006173}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:29:12,816] Trial 46 finished with value: 0.953247711845243 and parameters: {'iterations': 471, 'depth': 4, 'learning_rate': 0.033849446068830204, 'l2_leaf_reg': 1.1525141094056721, 'border_count': 34, 'random_strength': 2.855272578925514, 'bagging_temperature': 0.17826386574762831, 'scale_pos_weight': 2.668696249875275}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:29:20,009] Trial 47 finished with value: 0.9537111805751693 and parameters: {'iterations': 438, 'depth': 6, 'learning_rate': 0.040768684330875174, 'l2_leaf_reg': 9.497801269386617, 'border_count': 141, 'random_strength': 3.0137293244638075, 'bagging_temperature': 0.4930217470609618, 'scale_pos_weight': 2.0606418361974956}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:29:29,401] Trial 48 finished with value: 0.9532791301351603 and parameters: {'iterations': 523, 'depth': 7, 'learning_rate': 0.0230432617124662, 'l2_leaf_reg': 5.911539624934548, 'border_count': 62, 'random_strength': 1.9519022703932494, 'bagging_temperature': 0.8676371010257407, 'scale_pos_weight': 5.04624858466399}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:29:36,611] Trial 49 finished with value: 0.9534767003118886 and parameters: {'iterations': 848, 'depth': 5, 'learning_rate': 0.058827718318677086, 'l2_leaf_reg': 7.633577563789099, 'border_count': 182, 'random_strength': 2.380141946310772, 'bagging_temperature': 0.29308200210259955, 'scale_pos_weight': 3.6624376894295594}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:29:43,314] Trial 50 finished with value: 0.9521439531716697 and parameters: {'iterations': 785, 'depth': 10, 'learning_rate': 0.09973370353034164, 'l2_leaf_reg': 8.174443353325424, 'border_count': 232, 'random_strength': 1.3307675319873478, 'bagging_temperature': 0.7253944553911418, 'scale_pos_weight': 2.6694331443476966}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:29:55,760] Trial 51 finished with value: 0.9536498623608999 and parameters: {'iterations': 644, 'depth': 7, 'learning_rate': 0.03135738983210335, 'l2_leaf_reg': 9.36222054950672, 'border_count': 90, 'random_strength': 2.5010218671367372, 'bagging_temperature': 0.21964980231141706, 'scale_pos_weight': 1.4205718803546454}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:30:07,931] Trial 52 finished with value: 0.9540108966284819 and parameters: {'iterations': 620, 'depth': 8, 'learning_rate': 0.0378115403035051, 'l2_leaf_reg': 9.980021702808152, 'border_count': 72, 'random_strength': 1.820922402152243, 'bagging_temperature': 0.18761183377913426, 'scale_pos_weight': 1.2915192918429232}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:30:15,632] Trial 53 finished with value: 0.9533204861758516 and parameters: {'iterations': 571, 'depth': 6, 'learning_rate': 0.05648882085685067, 'l2_leaf_reg': 9.012832958279125, 'border_count': 96, 'random_strength': 3.157285921627504, 'bagging_temperature': 0.3941062986738084, 'scale_pos_weight': 1.9686150571381478}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:30:28,773] Trial 54 finished with value: 0.953091458546289 and parameters: {'iterations': 489, 'depth': 9, 'learning_rate': 0.041804160474754035, 'l2_leaf_reg': 8.780154809601857, 'border_count': 47, 'random_strength': 2.3258646937709977, 'bagging_temperature': 0.2774455399225324, 'scale_pos_weight': 2.6187568581712046}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:30:40,804] Trial 55 finished with value: 0.9536537410947524 and parameters: {'iterations': 628, 'depth': 7, 'learning_rate': 0.014387231150963197, 'l2_leaf_reg': 9.559771693548424, 'border_count': 104, 'random_strength': 0.9773947516746821, 'bagging_temperature': 0.22458039405307478, 'scale_pos_weight': 4.220588074627219}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:30:46,873] Trial 56 finished with value: 0.9524981024699838 and parameters: {'iterations': 278, 'depth': 8, 'learning_rate': 0.04875480049568461, 'l2_leaf_reg': 8.301798493972115, 'border_count': 137, 'random_strength': 5.7024242770962115, 'bagging_temperature': 0.09981948341088856, 'scale_pos_weight': 2.367449141766641}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:31:46,870] Trial 57 finished with value: 0.9526520814306657 and parameters: {'iterations': 746, 'depth': 13, 'learning_rate': 0.044407899535853376, 'l2_leaf_reg': 9.46013142505977, 'border_count': 157, 'random_strength': 2.6375727684542087, 'bagging_temperature': 0.004185236748660753, 'scale_pos_weight': 1.0011445538423307}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:31:55,286] Trial 58 finished with value: 0.9545613494078541 and parameters: {'iterations': 973, 'depth': 5, 'learning_rate': 0.062100426648455484, 'l2_leaf_reg': 8.787120633140065, 'border_count': 125, 'random_strength': 1.6441942007547028, 'bagging_temperature': 0.1488245192154684, 'scale_pos_weight': 1.9677794515334774}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:32:04,045] Trial 59 finished with value: 0.9539065361210238 and parameters: {'iterations': 986, 'depth': 4, 'learning_rate': 0.06325664065286403, 'l2_leaf_reg': 6.942317904536211, 'border_count': 171, 'random_strength': 1.046690241091673, 'bagging_temperature': 0.1123942813000742, 'scale_pos_weight': 2.94918080049358}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:32:11,415] Trial 60 finished with value: 0.9538476078077335 and parameters: {'iterations': 931, 'depth': 5, 'learning_rate': 0.06795099698129622, 'l2_leaf_reg': 8.769590287097177, 'border_count': 194, 'random_strength': 4.099872298778385, 'bagging_temperature': 0.15564577553828302, 'scale_pos_weight': 1.8820779724956889}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:32:18,487] Trial 61 finished with value: 0.9532216790984723 and parameters: {'iterations': 962, 'depth': 6, 'learning_rate': 0.05334538566016888, 'l2_leaf_reg': 9.07391617095507, 'border_count': 128, 'random_strength': 1.6551236114480004, 'bagging_temperature': 0.2570604954115682, 'scale_pos_weight': 1.443529031939537}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:32:30,265] Trial 62 finished with value: 0.9540971802395214 and parameters: {'iterations': 891, 'depth': 7, 'learning_rate': 0.03622810886584456, 'l2_leaf_reg': 9.69714324570788, 'border_count': 150, 'random_strength': 5.2580435597769855, 'bagging_temperature': 0.3240234261805256, 'scale_pos_weight': 2.249375834126325}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:32:38,941] Trial 63 finished with value: 0.9541140036015786 and parameters: {'iterations': 858, 'depth': 5, 'learning_rate': 0.05510484905984972, 'l2_leaf_reg': 7.480569050421099, 'border_count': 103, 'random_strength': 1.366180288051426, 'bagging_temperature': 0.06223929320497712, 'scale_pos_weight': 3.125990075358482}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:32:49,223] Trial 64 finished with value: 0.9541139297698491 and parameters: {'iterations': 965, 'depth': 6, 'learning_rate': 0.03249939150897306, 'l2_leaf_reg': 7.951161174633005, 'border_count': 121, 'random_strength': 0.759465354174959, 'bagging_temperature': 0.200170506416176, 'scale_pos_weight': 1.4744546442011348}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:32:56,922] Trial 65 finished with value: 0.9539511535981083 and parameters: {'iterations': 913, 'depth': 7, 'learning_rate': 0.04653559843913106, 'l2_leaf_reg': 8.203975562143071, 'border_count': 42, 'random_strength': 2.1410116845021516, 'bagging_temperature': 0.001461172019270443, 'scale_pos_weight': 1.893635845292009}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:33:04,445] Trial 66 finished with value: 0.9531804681531799 and parameters: {'iterations': 816, 'depth': 8, 'learning_rate': 0.06169596536057894, 'l2_leaf_reg': 8.61827491232231, 'border_count': 136, 'random_strength': 5.098758527427338, 'bagging_temperature': 0.13207193696422126, 'scale_pos_weight': 2.480943983834671}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:33:11,411] Trial 67 finished with value: 0.9538701460666518 and parameters: {'iterations': 939, 'depth': 6, 'learning_rate': 0.050511319808044526, 'l2_leaf_reg': 9.257963434825479, 'border_count': 70, 'random_strength': 1.6618738232683175, 'bagging_temperature': 1.4988323911971315, 'scale_pos_weight': 3.6304119518566034}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:33:19,056] Trial 68 finished with value: 0.9539194065964915 and parameters: {'iterations': 592, 'depth': 4, 'learning_rate': 0.0435004666890904, 'l2_leaf_reg': 9.96646697411036, 'border_count': 203, 'random_strength': 3.550728941151324, 'bagging_temperature': 0.3646518804459362, 'scale_pos_weight': 2.88049128015322}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:33:27,574] Trial 69 finished with value: 0.9531439063597852 and parameters: {'iterations': 832, 'depth': 3, 'learning_rate': 0.039653150810194465, 'l2_leaf_reg': 8.928800178508832, 'border_count': 156, 'random_strength': 4.703001828619534, 'bagging_temperature': 0.5951352935724977, 'scale_pos_weight': 1.2495866618173812}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:33:32,500] Trial 70 finished with value: 0.9520993193232016 and parameters: {'iterations': 874, 'depth': 7, 'learning_rate': 0.07053963552914772, 'l2_leaf_reg': 2.881905996563189, 'border_count': 168, 'random_strength': 5.636347840056015, 'bagging_temperature': 0.7931108100167938, 'scale_pos_weight': 7.078691332488303}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:33:45,161] Trial 71 finished with value: 0.954130672559019 and parameters: {'iterations': 720, 'depth': 8, 'learning_rate': 0.04812559522817771, 'l2_leaf_reg': 8.520859937058006, 'border_count': 111, 'random_strength': 4.0021694243541805, 'bagging_temperature': 0.08344216745240246, 'scale_pos_weight': 1.5766138057155306}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:33:55,701] Trial 72 finished with value: 0.9537438408431779 and parameters: {'iterations': 699, 'depth': 8, 'learning_rate': 0.049548687837310666, 'l2_leaf_reg': 8.134503159036647, 'border_count': 88, 'random_strength': 3.5459906963891967, 'bagging_temperature': 0.2578476756601996, 'scale_pos_weight': 2.2668015398742827}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:34:05,727] Trial 73 finished with value: 0.9537993549204957 and parameters: {'iterations': 645, 'depth': 8, 'learning_rate': 0.05719651938818642, 'l2_leaf_reg': 8.568454342281166, 'border_count': 120, 'random_strength': 3.746022603024788, 'bagging_temperature': 0.05325589191176871, 'scale_pos_weight': 1.7537792438482291}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:34:14,227] Trial 74 finished with value: 0.9515475516970314 and parameters: {'iterations': 554, 'depth': 10, 'learning_rate': 0.0659944964528643, 'l2_leaf_reg': 9.158351075507715, 'border_count': 146, 'random_strength': 2.9681172864857834, 'bagging_temperature': 0.160596241519087, 'scale_pos_weight': 8.62424220818193}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:34:24,747] Trial 75 finished with value: 0.9524893681763986 and parameters: {'iterations': 681, 'depth': 7, 'learning_rate': 0.029447525713560074, 'l2_leaf_reg': 7.654080641934888, 'border_count': 132, 'random_strength': 6.278710598465582, 'bagging_temperature': 0.0920839095379046, 'scale_pos_weight': 9.751410523865754}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:34:33,659] Trial 76 finished with value: 0.9544246727524479 and parameters: {'iterations': 751, 'depth': 5, 'learning_rate': 0.05168504490462114, 'l2_leaf_reg': 4.5754284830206915, 'border_count': 180, 'random_strength': 4.384383532771039, 'bagging_temperature': 1.1452589708348304, 'scale_pos_weight': 2.0319916292606237}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:34:44,904] Trial 77 finished with value: 0.9544872647245529 and parameters: {'iterations': 806, 'depth': 5, 'learning_rate': 0.037057213221123715, 'l2_leaf_reg': 4.77590977235587, 'border_count': 176, 'random_strength': 4.271522410177767, 'bagging_temperature': 1.2016005715591997, 'scale_pos_weight': 2.0905130238421314}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:34:55,372] Trial 78 finished with value: 0.9545637540751793 and parameters: {'iterations': 746, 'depth': 5, 'learning_rate': 0.036515001128753014, 'l2_leaf_reg': 4.412037181246454, 'border_count': 189, 'random_strength': 4.429938937694809, 'bagging_temperature': 1.269186544160423, 'scale_pos_weight': 2.5156974558856025}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:35:06,977] Trial 79 finished with value: 0.9541827496088308 and parameters: {'iterations': 795, 'depth': 5, 'learning_rate': 0.036761409768840556, 'l2_leaf_reg': 4.48121667849518, 'border_count': 189, 'random_strength': 4.392250112050821, 'bagging_temperature': 1.205911883618351, 'scale_pos_weight': 2.0994377259494574}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:35:18,050] Trial 80 finished with value: 0.9543962815634351 and parameters: {'iterations': 751, 'depth': 5, 'learning_rate': 0.03350042762744055, 'l2_leaf_reg': 4.234545342869907, 'border_count': 208, 'random_strength': 4.775113602280142, 'bagging_temperature': 1.196990532600085, 'scale_pos_weight': 2.4472303634523307}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:35:28,554] Trial 81 finished with value: 0.9539141639016907 and parameters: {'iterations': 736, 'depth': 5, 'learning_rate': 0.02466664198935821, 'l2_leaf_reg': 4.447699736288376, 'border_count': 220, 'random_strength': 4.788803489527996, 'bagging_temperature': 1.2232813663926059, 'scale_pos_weight': 2.6104861739672076}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:35:38,269] Trial 82 finished with value: 0.9539167672726702 and parameters: {'iterations': 759, 'depth': 4, 'learning_rate': 0.03390372003173222, 'l2_leaf_reg': 3.762288545659597, 'border_count': 179, 'random_strength': 4.25600426183552, 'bagging_temperature': 1.1412529689252011, 'scale_pos_weight': 2.784066829964535}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:35:48,928] Trial 83 finished with value: 0.9536953202356693 and parameters: {'iterations': 803, 'depth': 5, 'learning_rate': 0.04349034570318989, 'l2_leaf_reg': 5.341172774515451, 'border_count': 209, 'random_strength': 5.047002199103328, 'bagging_temperature': 1.3289798334498601, 'scale_pos_weight': 2.3865871608564038}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:35:56,533] Trial 84 finished with value: 0.9542862141843035 and parameters: {'iterations': 906, 'depth': 4, 'learning_rate': 0.08052108580326026, 'l2_leaf_reg': 4.7165796886347255, 'border_count': 189, 'random_strength': 4.459345733383667, 'bagging_temperature': 1.0281817463994547, 'scale_pos_weight': 3.3099385321870773}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:36:07,775] Trial 85 finished with value: 0.9542192831535639 and parameters: {'iterations': 766, 'depth': 5, 'learning_rate': 0.02917414881090357, 'l2_leaf_reg': 3.6760642047614676, 'border_count': 182, 'random_strength': 4.230736344833273, 'bagging_temperature': 1.2506712170417411, 'scale_pos_weight': 1.9665118197885183}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:36:16,652] Trial 86 finished with value: 0.9524438040481402 and parameters: {'iterations': 839, 'depth': 3, 'learning_rate': 0.02142605802574303, 'l2_leaf_reg': 4.967954551732677, 'border_count': 205, 'random_strength': 5.2218345570164, 'bagging_temperature': 1.154984779457178, 'scale_pos_weight': 2.447184604421499}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:36:23,741] Trial 87 finished with value: 0.9531721132904821 and parameters: {'iterations': 698, 'depth': 6, 'learning_rate': 0.04611961865559354, 'l2_leaf_reg': 5.7827897320472585, 'border_count': 218, 'random_strength': 4.7681092754453225, 'bagging_temperature': 1.3016689631833631, 'scale_pos_weight': 9.345528942011473}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:36:34,037] Trial 88 finished with value: 0.9548815698164447 and parameters: {'iterations': 766, 'depth': 5, 'learning_rate': 0.04135779841852554, 'l2_leaf_reg': 4.009900124345467, 'border_count': 160, 'random_strength': 5.590593860453465, 'bagging_temperature': 1.0677151190167435, 'scale_pos_weight': 2.161384172162749}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:36:43,996] Trial 89 finished with value: 0.9540623335893009 and parameters: {'iterations': 866, 'depth': 4, 'learning_rate': 0.03812556048386725, 'l2_leaf_reg': 3.33936307117295, 'border_count': 159, 'random_strength': 5.931017443606984, 'bagging_temperature': 1.000533792572628, 'scale_pos_weight': 2.179078240297217}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:36:55,404] Trial 90 finished with value: 0.9541975316840746 and parameters: {'iterations': 978, 'depth': 6, 'learning_rate': 0.04187491156035578, 'l2_leaf_reg': 3.9729974091605125, 'border_count': 178, 'random_strength': 7.0120234288126895, 'bagging_temperature': 1.0873011407652824, 'scale_pos_weight': 1.8119514457079169}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:37:06,530] Trial 91 finished with value: 0.9542151460086586 and parameters: {'iterations': 766, 'depth': 5, 'learning_rate': 0.03143675912758807, 'l2_leaf_reg': 4.175628086746312, 'border_count': 195, 'random_strength': 5.625814407534395, 'bagging_temperature': 1.3679797944626402, 'scale_pos_weight': 3.0539261619464395}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:37:15,777] Trial 92 finished with value: 0.9547440781229475 and parameters: {'iterations': 731, 'depth': 5, 'learning_rate': 0.052329007724094746, 'l2_leaf_reg': 5.094481437155571, 'border_count': 171, 'random_strength': 5.481588634215202, 'bagging_temperature': 1.1518418215140993, 'scale_pos_weight': 2.5772859365939405}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:37:22,312] Trial 93 finished with value: 0.9526724827425298 and parameters: {'iterations': 670, 'depth': 6, 'learning_rate': 0.05201618183012443, 'l2_leaf_reg': 3.1349078999885402, 'border_count': 168, 'random_strength': 5.545215424874087, 'bagging_temperature': 1.149553846625291, 'scale_pos_weight': 7.8844819117515605}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:37:31,457] Trial 94 finished with value: 0.9543898373374905 and parameters: {'iterations': 729, 'depth': 4, 'learning_rate': 0.05556490564307098, 'l2_leaf_reg': 2.4362906526975503, 'border_count': 174, 'random_strength': 5.816334878211356, 'bagging_temperature': 1.1003323714091382, 'scale_pos_weight': 2.748474682715731}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:37:40,775] Trial 95 finished with value: 0.9534913019809063 and parameters: {'iterations': 807, 'depth': 6, 'learning_rate': 0.04120035225987625, 'l2_leaf_reg': 5.150492160194273, 'border_count': 164, 'random_strength': 5.392348048307424, 'bagging_temperature': 0.9778023785361838, 'scale_pos_weight': 6.107551607280662}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:37:50,354] Trial 96 finished with value: 0.9543377130995735 and parameters: {'iterations': 780, 'depth': 5, 'learning_rate': 0.05900148999808555, 'l2_leaf_reg': 4.80418358581503, 'border_count': 152, 'random_strength': 6.120315155692933, 'bagging_temperature': 1.2972831534144666, 'scale_pos_weight': 2.095555066008646}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:37:59,632] Trial 97 finished with value: 0.9540347243746045 and parameters: {'iterations': 829, 'depth': 5, 'learning_rate': 0.046770080845301654, 'l2_leaf_reg': 6.15073348314761, 'border_count': 183, 'random_strength': 5.091555951078027, 'bagging_temperature': 0.8919713165998496, 'scale_pos_weight': 2.5655855231209816}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:38:08,593] Trial 98 finished with value: 0.9543518528387716 and parameters: {'iterations': 696, 'depth': 5, 'learning_rate': 0.05165738600627724, 'l2_leaf_reg': 5.647441052006352, 'border_count': 169, 'random_strength': 3.905384242794254, 'bagging_temperature': 1.088736619118278, 'scale_pos_weight': 3.211733964242236}. Best is trial 21 with value: 0.9550143699850512.
# [I 2024-10-15 12:38:17,799] Trial 99 finished with value: 0.9537799634982864 and parameters: {'iterations': 716, 'depth': 4, 'learning_rate': 0.038905347197173624, 'l2_leaf_reg': 3.9178232114552496, 'border_count': 188, 'random_strength': 4.923775876949773, 'bagging_temperature': 1.398243705429124, 'scale_pos_weight': 1.1919075330635511}. Best is trial 21 with value: 0.9550143699850512.

# %%
study.best_params, study.best_value
# Out:
# ({'iterations': 891,
#   'depth': 7,
#   'learning_rate': 0.0448563477253477,
#   'l2_leaf_reg': 8.309884320742215,
#   'border_count': 161,
#   'random_strength': 5.297381835241815,
#   'bagging_temperature': 0.10498408144882451,
#   'scale_pos_weight': 2.3753101495123747},
#  0.9550143699850512)

# %% [markdown]
# # final training

# %%
NUM_FOLD = 5

train = pd.read_csv('../dataset/train.csv', index_col='id')
test = pd.read_csv('../dataset/test.csv', index_col='id')
original = pd.read_csv('../dataset/original.csv')


# cat_cols = list(test.select_dtypes(include=['object']).columns)
cat_cols = test.columns.values

for df in [train, test, original]:
    for col in cat_cols:
        df[col] = df[col].astype('str').astype('category')


X = train.drop(['loan_status'], axis=1)
y = train['loan_status']
X_original = original.drop(['loan_status'], axis=1)
y_original = original['loan_status']

# %%
val_scores = []
test_preds_model = []

skf = StratifiedKFold(n_splits=NUM_FOLD, shuffle=True, random_state=42)


# test 1
params = {'iterations': 891,
  'depth': 7,
  'learning_rate': 0.0448563477253477,
  'l2_leaf_reg': 8.309884320742215,
  'border_count': 161,
  'random_strength': 5.297381835241815,
  'bagging_temperature': 0.10498408144882451,
  'scale_pos_weight': 2.3753101495123747}

for Fold, (train_index, val_index) in enumerate(skf.split(X, y)):

    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y[train_index], y[val_index]

    X_train = pd.concat([X_train, X_original], axis=0)
    y_train = pd.concat([y_train, y_original]) 

    model = CatBoostClassifier(**params,cat_features=cat_cols)
    # model.fit(X_train, y_train)
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=100, verbose=False)

    y_pred = model.predict_proba(X_val)[:, 1]

    roc_auc_score_ = roc_auc_score(y_val, y_pred)

    print(f'Fold {Fold}: roc_auc_score= {roc_auc_score_:.5f}')

    val_scores.append(roc_auc_score_)

    test_preds_model.append(model.predict_proba(test)[:, 1])

test_preds_model = sum(test_preds_model)/len(test_preds_model)

print(f'mean validation roc_auc_score = {np.mean(val_scores):.5f}')
print(f'std validation roc_auc_score = {np.std(val_scores):.5f}')
# Out:
# Fold 0: roc_auc_score= 0.96436
# Fold 1: roc_auc_score= 0.97157
# Fold 2: roc_auc_score= 0.96897
# Fold 3: roc_auc_score= 0.97142
# Fold 4: roc_auc_score= 0.96759
# mean validation roc_auc_score = 0.96878
# std validation roc_auc_score = 0.00268
